# %%
import pandas as pd
import numpy as np
from numpy import random
import matplotlib
from  matplotlib import pyplot as plt
# %matplotlib inline
import sys

print('Python version' + ' ' + sys.version)
print('Pandas version' + ' ' + pd.__version__)
print('Matplotlib ersion' + ' ' + matplotlib.__version__)
# Out:
# Python version 3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]
# Pandas version 1.4.4
# Matplotlib ersion 3.5.2

# %%
from pandas import DataFrame, read_excel
df= pd.read_excel(r'C:\Users\cctro\OneDrive\桌面\Desktop20221230\fmct2020\fmct_xlsx folder\fmct202301.xlsx', date_parser=True)
df.tail(3)
pd.options.display.max_columns=62
pd.options.display.precision=3
df.tail(1)
# Out:
#     Unnamed: 0   No     ID 狀態    姓名         身份證  病患目前狀態 檢驗  造管   出院   離開  \
# 255          Y  256  17238  ◎  蘇蔡秀珍  K200845501  長期血液透析  ★ NaN  NaN  NaN
#
#       本院開始透析日期             進入原因                                 轉入診所  \
# 255  2016/10/1  1.New ESRD Case  9998 non FMC center (closed center)
#
#             生日   性別    婚姻   開始常規HD日期         原發病細類    透析處方日期  身高  理想乾體重  每週次數  \
# 255  1948/1/15  2 女  1 已婚  2016/6/26  C-03 腎尿路惡性腫瘤  2023/1/5 NaN   51.5     3
#
#      第一次腎移植日期 週邊血管疾病  抽煙  HBsAg Anti-HCV 狀態異動日期 狀態異動原因 死亡原因細項  ...  \
# 255       NaN     No  No  陰性(-)    陰性(-)    NaN    NaN    NaN  ...
#
#      Kt/V (Gotch) Kt/V (Daugirdas)     EPO route Vitamin D route  \
# 255          1.46            1.665  Subcutaneous            Oral
#
#     Current IV Iron Current Vitamin D CreactiveProtein  HBA1c  Total CO2  \
# 255            50.0               1.5              NaN    0.0        NaN
#
#      Antihypertensive Drug Score  (HD檢驗)HBsAg  (HD檢驗)Anti-HCV CAD  CVD  \
# 255                          0.0        陰性(-)           陰性(-)  No   No
#
#      Malignant  Liver  Diabetes 本次透析脫水量               透析方式  透析模式  稀釋法  置換液量  \
# 255         No     No        No     1.5  High efficient HD   NaN  NaN   NaN
#
#        驗證碼  外籍人士  病患進入原因  病患死亡原因  病患轉出原因  RELOH   LTI  Ret_Hb   WBC
# 255  0.591    No     CKD     NaN     NaN    3.2  15.0    34.3  6.24
#
# [1 rows x 97 columns]

# %%
from pandas import DataFrame, read_csv
df= pd.read_csv(r'C:\Users\cctro\OneDrive\桌面\Desktop20221230\fmct2020\fmct_kpis202304.csv', date_parser=True)
df.tail(3)
pd.options.display.max_columns=62
pd.options.display.precision=3
df.tail(1)
# Out:
#         姓名         身份證      性別   開始常規HD日期         原發病細類    透析處方日期  身高  理想乾體重  \
# 1020  蘇蔡秀珍  K200845501  Female  2016/6/26  C-03 腎尿路惡性腫瘤  2023/2/8 NaN   51.8
#
#       每週次數 週邊血管疾病  抽煙  HBsAg Anti-HCV 當月檢驗血管通路    HD檢驗日期  透析前體重  透析後體重  \
# 1020     3     No  No  陰性(-)    陰性(-)      AVF  2023/2/8  54.75   52.7
#
#       本次透析時間  血液流速  透析液流速    透析器型號  透析前收縮壓  透析後收縮壓  透析前舒張壓  透析後舒張壓  \
# 1020   240.0   280    500  BG-1.8U     142     140      76      76
#
#                        EPO種類   EPO劑量  透析前BUN  透析後BUN  Creatinine     Na  ...  \
# 1020  2 Epoepin-b (Recormon)  5349.0    80.0    15.0       10.79  141.0  ...
#
#       CAD  CVD  Malignant  Liver  Diabetes  透析模式 病患進入原因  病患死亡原因 RELOH   LTI  \
# 1020   No   No         No     No        No   NaN    CKD     NaN   3.2  15.0
#
#       Vol_mgmt %    CAP  Vol changed %  Ret_Hb PreBpsys_code   ReOH_code  \
# 1020        0.04  36.19           3.96    34.3             0  ReOH <= 13
#
#       AHTN  Score AHTN Score Code  TSAT_Code    ESA_Code     KtV_Code  \
# 1020          0.0      AHTN > 2.0  TSAT < 50  ESA < 8000  Kt/V >= 1.8
#
#             Ret_Hb_Code        IronTx_Code        Hbc_Code        VA_Code  \
# 1020  Ret_Hb_Code >= 29  IronTx_Code <= 50  Hbc_Code >= 10  VA_Code = AVF
#
#              Alb_Code         A1c_Code         P_Code       PTH  \
# 1020  Alb_Code >= 3.8  A1c_Code <= 6.5  P_Code <= 5.5  PTH<=585
#
#      Patient Month Year Month-Year
# 1020       蘇蔡秀珍Feb-2023   Feb-2023
#
# [1 rows x 90 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1021 entries, 0 to 1020
# Data columns (total 90 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   姓名                     1021 non-null   object
#  1   身份證                    1021 non-null   object
#  2   性別                     1021 non-null   object
#  3   開始常規HD日期               1021 non-null   object
#  4   原發病細類                  1021 non-null   object
#  5   透析處方日期                 1021 non-null   object
#  6   身高                     241 non-null    float64
#  7   理想乾體重                  1021 non-null   float64
#  8   每週次數                   1021 non-null   int64
#  9   週邊血管疾病                 1021 non-null   object
#  10  抽煙                     1021 non-null   object
#  11  HBsAg                  1021 non-null   object
#  12  Anti-HCV               1021 non-null   object
#  13  當月檢驗血管通路               1009 non-null   object
#  14  HD檢驗日期                 1021 non-null   object
#  15  透析前體重                  1019 non-null   float64
#  16  透析後體重                  1019 non-null   float64
#  17  本次透析時間                 1019 non-null   float64
#  18  血液流速                   1021 non-null   int64
#  19  透析液流速                  1021 non-null   int64
#  20  透析器型號                  1021 non-null   object
#  21  透析前收縮壓                 1021 non-null   int64
#  22  透析後收縮壓                 1021 non-null   int64
#  23  透析前舒張壓                 1021 non-null   int64
#  24  透析後舒張壓                 1021 non-null   int64
#  25  EPO種類                  971 non-null    object
#  26  EPO劑量                  983 non-null    float64
#  27  透析前BUN                 1019 non-null   float64
#  28  透析後BUN                 1019 non-null   float64
#  29  Creatinine             1019 non-null   float64
#  30  Na                     1019 non-null   float64
#  31  Albumin                1019 non-null   float64
#  32  K                      1019 non-null   float64
#  33  Alkaline-P             1019 non-null   float64
#  34  全鈣                     1019 non-null   float64
#  35  Hbc                    1019 non-null   float64
#  36  P                      1019 non-null   float64
#  37  iPTH                   524 non-null    object
#  38  OCM Kt/V               1019 non-null   float64
#  39  EPO route              1021 non-null   object
#  40  Vitamin D route        1021 non-null   object
#  41  Current IV Iron        1019 non-null   float64
#  42  Current Vitamin D      1019 non-null   float64
#  43  AHTN Drug Score        1019 non-null   float64
#  44  本次透析脫水量                1021 non-null   float64
#  45  透析方式                   1021 non-null   object
#  46  Kt/V (Gotch)           1012 non-null   float64
#  47  Kt/V (Daugirdas)       1015 non-null   float64
#  48  本院開始透析日期               1021 non-null   object
#  49  進入原因                   1021 non-null   object
#  50  生日                     1021 non-null   object
#  51  死亡原因細項                 5 non-null      object
#  52  TIBC                   754 non-null    float64
#  53  Tranferrin saturation  754 non-null    float64
#  54  Ferritin               754 non-null    object
#  55  Fe                     754 non-null    float64
#  56  HBA1c                  630 non-null    float64
#  57  (HD檢驗)HBsAg            1021 non-null   object
#  58  (HD檢驗)Anti-HCV         1021 non-null   object
#  59  CAD                    1021 non-null   object
#  60  CVD                    1021 non-null   object
#  61  Malignant              1021 non-null   object
#  62  Liver                  1021 non-null   object
#  63  Diabetes               1021 non-null   object
#  64  透析模式                   31 non-null     object
#  65  病患進入原因                 1021 non-null   object
#  66  病患死亡原因                 5 non-null      object
#  67  RELOH                  968 non-null    float64
#  68  LTI                    968 non-null    float64
#  69  Vol_mgmt %             1021 non-null   float64
#  70  CAP                    1019 non-null   float64
#  71  Vol changed %          1021 non-null   float64
#  72  Ret_Hb                 1005 non-null   float64
#  73  PreBpsys_code          1021 non-null   object
#  74  ReOH_code              1021 non-null   object
#  75  AHTN  Score            1019 non-null   float64
#  76  AHTN Score Code        1021 non-null   object
#  77  TSAT_Code              1021 non-null   object
#  78  ESA_Code               1021 non-null   object
#  79  KtV_Code               1021 non-null   object
#  80  Ret_Hb_Code            1021 non-null   object
#  81  IronTx_Code            1021 non-null   object
#  82  Hbc_Code               1021 non-null   object
#  83  VA_Code                1021 non-null   object
#  84  Alb_Code               1021 non-null   object
#  85  A1c_Code               1021 non-null   object
#  86  P_Code                 1021 non-null   object
#  87  PTH                    1021 non-null   object
#  88  Patient Month Year     1021 non-null   object
#  89  Month-Year             1021 non-null   object
# dtypes: float64(34), int64(7), object(49)
# memory usage: 718.0+ KB

# %%
from pylab import rcParams
import seaborn as sns

rcParams['figure.figsize']= 6,4
sns.set_style('whitegrid')

# %%
df.columns
# Out:
# Index(['姓名', '身份證', '性別', '開始常規HD日期', '原發病細類', '透析處方日期', '身高', '理想乾體重', '每週次數',
#        '週邊血管疾病', '抽煙', 'HBsAg', 'Anti-HCV', '當月檢驗血管通路', 'HD檢驗日期', '透析前體重',
#        '透析後體重', '本次透析時間', '血液流速', '透析液流速', '透析器型號', '透析前收縮壓', '透析後收縮壓',
#        '透析前舒張壓', '透析後舒張壓', 'EPO種類', 'EPO劑量', '透析前BUN', '透析後BUN', 'Creatinine',
#        'Na', 'Albumin', 'K', 'Alkaline-P', '全鈣', 'Hbc', 'P', 'iPTH',
#        'OCM Kt/V', 'EPO route', 'Vitamin D route', 'Current IV Iron',
#        'Current Vitamin D', 'AHTN Drug Score', '本次透析脫水量', '透析方式',
#        'Kt/V (Gotch)', 'Kt/V (Daugirdas)', '本院開始透析日期', '進入原因', '生日', '死亡原因細項',
#        'TIBC', 'Tranferrin saturation', 'Ferritin', 'Fe', 'HBA1c',
#        '(HD檢驗)HBsAg', '(HD檢驗)Anti-HCV', 'CAD', 'CVD', 'Malignant', 'Liver',
#        'Diabetes', '透析模式', '病患進入原因', '病患死亡原因', 'RELOH', 'LTI', 'Vol_mgmt %',
#        'CAP', 'Vol changed %', 'Ret_Hb', 'PreBpsys_code', 'ReOH_code',
#        'AHTN  Score', 'AHTN Score Code', 'TSAT_Code', 'ESA_Code', 'KtV_Code',
#        'Ret_Hb_Code', 'IronTx_Code', 'Hbc_Code', 'VA_Code', 'Alb_Code',
#        'A1c_Code', 'P_Code', 'PTH', 'Patient Month Year', 'Month-Year'],
#       dtype='object')

# %%
df_hemodynamics=df[['性別','透析前收縮壓', 'AHTN Drug Score','Vol changed %','RELOH','PreBpsys_code', 'ReOH_code']]

# %%
sns.pairplot(df_hemodynamics, vars=['透析前收縮壓', 'AHTN Drug Score','Vol changed %','RELOH'],
             hue='性別')
# Out:
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 36879 (\N{CJK UNIFIED IDEOGRAPH-900F}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 26512 (\N{CJK UNIFIED IDEOGRAPH-6790}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 21069 (\N{CJK UNIFIED IDEOGRAPH-524D}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 25910 (\N{CJK UNIFIED IDEOGRAPH-6536}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 32302 (\N{CJK UNIFIED IDEOGRAPH-7E2E}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 22739 (\N{CJK UNIFIED IDEOGRAPH-58D3}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 36879 (\N{CJK UNIFIED IDEOGRAPH-900F}) missing from current font.
#   fig.canvas.draw()
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 26512 (\N{CJK UNIFIED IDEOGRAPH-6790}) missing from current font.
#   fig.canvas.draw()
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 21069 (\N{CJK UNIFIED IDEOGRAPH-524D}) missing from current font.
#   fig.canvas.draw()
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 25910 (\N{CJK UNIFIED IDEOGRAPH-6536}) missing from current font.
#   fig.canvas.draw()
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 32302 (\N{CJK UNIFIED IDEOGRAPH-7E2E}) missing from current font.
#   fig.canvas.draw()
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 22739 (\N{CJK UNIFIED IDEOGRAPH-58D3}) missing from current font.
#   fig.canvas.draw()
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 24615 (\N{CJK UNIFIED IDEOGRAPH-6027}) missing from current font.
#   fig.canvas.draw()
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 21029 (\N{CJK UNIFIED IDEOGRAPH-5225}) missing from current font.
#   fig.canvas.draw()
# C:\Users\cctro\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 36879 (\N{CJK UNIFIED IDEOGRAPH-900F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\cctro\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 26512 (\N{CJK UNIFIED IDEOGRAPH-6790}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\cctro\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 21069 (\N{CJK UNIFIED IDEOGRAPH-524D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\cctro\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 25910 (\N{CJK UNIFIED IDEOGRAPH-6536}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\cctro\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 32302 (\N{CJK UNIFIED IDEOGRAPH-7E2E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\cctro\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 22739 (\N{CJK UNIFIED IDEOGRAPH-58D3}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\cctro\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 24615 (\N{CJK UNIFIED IDEOGRAPH-6027}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\cctro\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 21029 (\N{CJK UNIFIED IDEOGRAPH-5225}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.pairplot(df_hemodynamics, vars=['透析前收縮壓', 'AHTN Drug Score','Vol changed %','RELOH'],
             hue='PreBpsys_code')
# Out:
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 36879 (\N{CJK UNIFIED IDEOGRAPH-900F}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 26512 (\N{CJK UNIFIED IDEOGRAPH-6790}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 21069 (\N{CJK UNIFIED IDEOGRAPH-524D}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 25910 (\N{CJK UNIFIED IDEOGRAPH-6536}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 32302 (\N{CJK UNIFIED IDEOGRAPH-7E2E}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 22739 (\N{CJK UNIFIED IDEOGRAPH-58D3}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 36879 (\N{CJK UNIFIED IDEOGRAPH-900F}) missing from current font.
#   fig.canvas.draw()
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 26512 (\N{CJK UNIFIED IDEOGRAPH-6790}) missing from current font.
#   fig.canvas.draw()
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 21069 (\N{CJK UNIFIED IDEOGRAPH-524D}) missing from current font.
#   fig.canvas.draw()
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 25910 (\N{CJK UNIFIED IDEOGRAPH-6536}) missing from current font.
#   fig.canvas.draw()
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 32302 (\N{CJK UNIFIED IDEOGRAPH-7E2E}) missing from current font.
#   fig.canvas.draw()
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 22739 (\N{CJK UNIFIED IDEOGRAPH-58D3}) missing from current font.
#   fig.canvas.draw()
# C:\Users\cctro\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 36879 (\N{CJK UNIFIED IDEOGRAPH-900F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\cctro\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 26512 (\N{CJK UNIFIED IDEOGRAPH-6790}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\cctro\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 21069 (\N{CJK UNIFIED IDEOGRAPH-524D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\cctro\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 25910 (\N{CJK UNIFIED IDEOGRAPH-6536}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\cctro\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 32302 (\N{CJK UNIFIED IDEOGRAPH-7E2E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\cctro\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 22739 (\N{CJK UNIFIED IDEOGRAPH-58D3}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.pairplot(df_hemodynamics, vars=['透析前收縮壓', 'Vol changed %','RELOH'],
             hue='ReOH_code')
# Out:
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 36879 (\N{CJK UNIFIED IDEOGRAPH-900F}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 26512 (\N{CJK UNIFIED IDEOGRAPH-6790}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 21069 (\N{CJK UNIFIED IDEOGRAPH-524D}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 25910 (\N{CJK UNIFIED IDEOGRAPH-6536}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 32302 (\N{CJK UNIFIED IDEOGRAPH-7E2E}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 22739 (\N{CJK UNIFIED IDEOGRAPH-58D3}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 36879 (\N{CJK UNIFIED IDEOGRAPH-900F}) missing from current font.
#   fig.canvas.draw()
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 26512 (\N{CJK UNIFIED IDEOGRAPH-6790}) missing from current font.
#   fig.canvas.draw()
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 21069 (\N{CJK UNIFIED IDEOGRAPH-524D}) missing from current font.
#   fig.canvas.draw()
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 25910 (\N{CJK UNIFIED IDEOGRAPH-6536}) missing from current font.
#   fig.canvas.draw()
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 32302 (\N{CJK UNIFIED IDEOGRAPH-7E2E}) missing from current font.
#   fig.canvas.draw()
# C:\Users\cctro\anaconda3\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 22739 (\N{CJK UNIFIED IDEOGRAPH-58D3}) missing from current font.
#   fig.canvas.draw()
# C:\Users\cctro\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 36879 (\N{CJK UNIFIED IDEOGRAPH-900F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\cctro\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 26512 (\N{CJK UNIFIED IDEOGRAPH-6790}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\cctro\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 21069 (\N{CJK UNIFIED IDEOGRAPH-524D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\cctro\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 25910 (\N{CJK UNIFIED IDEOGRAPH-6536}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\cctro\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 32302 (\N{CJK UNIFIED IDEOGRAPH-7E2E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\cctro\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 22739 (\N{CJK UNIFIED IDEOGRAPH-58D3}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
